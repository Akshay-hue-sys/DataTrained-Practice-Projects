# %% [markdown]
# ## IMPORTED THE NECESSARY LIBRARIES AND LOADING THE DATASET:-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('titanic_practice_project.csv',index_col='PassengerId')
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# loaded the dataset and named it as 'df'.used head function to display the first 5 rows of the dataset.

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# THERE ARE 891 ROWS AND 12 COLUMNS IN THE DATASET.

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS:--
# EXPLORATORY DATA ANALYSIS INVOLVES THE FOLLOWING PROCESS:-
#
# 1.READ THE DATA
#
# 2.VARIABLE IDENTIFICATION
#
# 3.UNIVARIATE ANALYSIS
#
# 4.BIVARIATE ANLAYSIS
#
# 5.DETECTING OUTLIERS/ANOMALY DETECTION
#
# 6.HANDLING /REMOVING NULL VALUES
#
# 7.HANDLING CATEGORICAL VARIABLES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# THERE ARE 4 COLUMNS OF INTEGER DATATYPE,5 COLUMNS OF OBJECT DATATYPE AND 2 COLUMNS OF FLOAT DATATYPE.
# THERE ARE MISSING VALUES IN AGE,EMBARKED AND CABIN COLUMN.
# CABIN COLUMN HAS THE GREAT NUMBER OF MISSING VALUES.

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# There are numerous statistics for each column in the whole dataset;They tells us about the important information regarding the dataset
#
# 1.min--minimum value.
#
# 2.max--maximum value.
#
# 3.std--standard deviation from the mean.
#
# 4.25%--the 25th percentile.
#
# 5.mean--average for each column.
#
# 6.50%--median or the 50th percentile for each column.
#
# 7.75%--75th percentile.
#
# 8.count-- it shows the total number of counts for each column.

# %%
df.describe(include='O')
# Out:
#                      Name   Sex    Ticket        Cabin Embarked
# count                 891   891       891          204      889
# unique                891     2       681          147        3
# top     Badt, Mr. Mohamed  male  CA. 2343  C23 C25 C27        S
# freq                    1   577         7            4      644

# %% [markdown]
# THERE ARE SOME CATEGORICAL COLUMNS IN THE DATASET:--SEX,EMBARKED,SURVIVED AND PCLASS.
#
#
# PCLASS AND SURVIVED ARE OF INTEGER DATATYPE BUT THEY ARE CATEGORICAL.
#
# THERE ARE 147 CABINS UNIQUE OUT OF THE 204 NON NULL VALUES.

# %% [markdown]
# ### MISSING VALUES TREATMENT:-

# %%
from sklearn.impute import SimpleImputer

# %%
age_m = SimpleImputer()
df['Age']=age_m.fit_transform(df['Age'].values.reshape(-1,1))[:,0]
df['Age'].value_counts()

cabin_embarked_i= SimpleImputer(strategy='most_frequent')
df['Cabin'] = cabin_embarked_i.fit_transform(df['Cabin'].values.reshape(-1,1))[:,0]
df['Cabin'].value_counts()
df['Embarked']=cabin_embarked_i.fit_transform(df['Embarked'].values.reshape(-1,1))[:,0]
df['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     891 non-null    object
#  10  Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# REMOVED THE NULL VALUES BY IMPUTING THE AGE COLUMN WITH MEAN/AVERAGE AGE,CABIN AND EMBARKED WITH MOST FREQUENT VALUES IN THEIR RESPECTIVE SERIES.

# %%
df['Ticket'].value_counts()
# Out:
# CA. 2343    7
# 347082      7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 112052      1
# 113807      1
# 345769      1
# 315037      1
# 383121      1
# Name: Ticket, Length: 681, dtype: int64

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        691
# C23 C25 C27      4
# G6               4
# D                3
# F2               3
#               ...
# C30              1
# A23              1
# D56              1
# B102             1
# E49              1
# Name: Cabin, Length: 147, dtype: int64

# %%
df = df.drop(['Name','Ticket'],axis=1)

# %% [markdown]
# I DO NOT NEED NAME AND TICKET COLUMNS FOR UNDERSTANDING THE RELATIONSHIP WITH THE OTHER COLUMNS OF THE DATASET BECAUSE THEY CANNOT HELP US PREDICT WHETHER A PARTICULAR PASSENGER WITH A PARTICULAR TICKET WILL SURVIVE OR NOT.

# %%
sns.countplot(data=df,x='Survived')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(data=df,x='Survived',hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# IT CAN BE SEEN THAT PASSENGERS IN PCLASS 3 HAS THE MOST DEATH RATE WHEREAS THE PASSENGERS IN PCLASS 1 HAS THE MOST SURVIVAL RATE.

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.countplot(data=df,x='SibSp',hue='Survived');

# %% [markdown]
# IT CAN BE SEEN FROM THE ABOVE CHART THAT MORE THE SIBLINGS THE PASSENGER HAVE,MORE THEY HAVE A CHANCE OF NOT SURVIVING.

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# According to the data above, it shows that the values of Survived column are either 0 or 1, where 0 represents that the passenger is not survived while 1 says that they are survived.
# The dataset is imbalanced and majority belongs to the '0' category.

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin',
#        'Embarked'],
#       dtype='object')

# %%
cols=df.columns
cols
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin',
#        'Embarked'],
#       dtype='object')

# %%
for i in cols:
    plt.figure(figsize=(12,8),dpi=200)
    sns.histplot(data=df,x=df[i],kde=True)

# %% [markdown]
# THERE ARE MORE MALE MEMBERS THAN FEMALE IN THE DATASET.
#
#
# THERE ARE MORE PASSENGERS BELONGING TO 3RD CLASS FOLLOWED BY 1ST AND 2ND CLASS.
#
#
# THE AGE COLUMN IS LOOKING MORE RIGHTLY SKEWED AND MOST PASSENGER COUNTS ARE AROUND THE AGE OF 30.
#
# THE SIBSP,PARCH AND FARE DATA SEEMS TO BE RIGHTLY SKEWED.
#
# MOST PASSENGER COUNTS ARE IN THE 'S' EMBARKED COLUMN.

# %%
df.skew()
# Out:
# Survived    0.478523
# Pclass     -0.630548
# Age         0.434488
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# dtype: float64

# %%
skew_data = df.skew()
skew_data
# Out:
# Survived    0.478523
# Pclass     -0.630548
# Age         0.434488
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# dtype: float64

# %%
skew_data = skew_data.reset_index()
skew_data
# Out:
#       index         0
# 0  Survived  0.478523
# 1    Pclass -0.630548
# 2       Age  0.434488
# 3     SibSp  3.695352
# 4     Parch  2.749117
# 5      Fare  4.787317

# %% [markdown]
# reset the index for skew data.

# %%
skew_data.rename(columns={'index':'column_names',0:'skewness'},inplace=True)

# %%
skew_data
# Out:
#   column_names  skewness
# 0     Survived  0.478523
# 1       Pclass -0.630548
# 2          Age  0.434488
# 3        SibSp  3.695352
# 4        Parch  2.749117
# 5         Fare  4.787317

# %%
skew_data.drop([0,1],axis=0,inplace=True)

# %% [markdown]
# I  AM NOT CONSIDERING THE SKEWNESS FOR THE TARGET LABEL-SURVIVED COLUMN AND THE CATEGORICAL COLUMN--PCLASS BECAUSE THEY AFFECT THE MODEL PERFORMANCE OF PREDICTION.

# %%
skew_data
# Out:
#   column_names  skewness
# 2          Age  0.434488
# 3        SibSp  3.695352
# 4        Parch  2.749117
# 5         Fare  4.787317

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.scatterplot(data=skew_data,x='column_names',y='skewness')
plt.xticks(rotation=90)
plt.yticks(np.arange(-5, 50, step=5))
plt.axhline(y = 0, color = 'g', linestyle = '-')
plt.axhline(y = 0.5, color = 'r', linestyle = '-')
plt.axhline(y = -0.5, color = 'r', linestyle = '-');

# %% [markdown]
# SKEWNESS CHECK AND OBSERVATIONS:- PLOTTED SKEWNESS FOR ALL DATA DISTRIBUTIONS AGAINST COLUMNS OF THE DATA. PLOTTED GREEN HORIZONTAL LINE FOR A SKEWNESS OF ZERO(NORMAL DISTRIBUTION HAS ASKEWNESS OF 0). PLOTTED RED LINES AROUND THE GREEN LINE DENOTING A RANGE OF(-0.5,0.5). IF DATA POINTS FALL WITHIN THE ABOVE MENTIONED RANGE,THEN THEY ARE APPROXIMATELY NORMALLY DISTRIBUTED .
#
# FOUND NO DATA POINTS WITHIN THE RANGE. ALL THE DATA POINTS ARE HIGHLY SKEWED. The rule for skewness seems to be: If the skewness is between -0.5 and 0.5, the data are fairly symmetrical. If the skewness is between -1 and -0.5 (negatively skewed) or between 0.5 and 1 (positively skewed), the data are moderately skewed.
#
# Skewness of the normal distribution is zero. All the dataset columns seem to have a skewness of more than 0.5 (except for the label) and even more than 1,so they all are highly skewed.They all have a right-skewed data or a positively-skewed data curve since the right tail is longer and mass of the distribution is concentrated on the left of the figure.
#
# ALL THE COLUMNS EXCEPT AGE SEEMS TO BE HIGHLY SKEWED.

# %% [markdown]
# ### ENCODING:-

# %%
df
# Out:
#              Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# PassengerId
# 1                   0       3    male  22.000000      1      0   7.2500
# 2                   1       1  female  38.000000      1      0  71.2833
# 3                   1       3  female  26.000000      0      0   7.9250
# 4                   1       1  female  35.000000      1      0  53.1000
# 5                   0       3    male  35.000000      0      0   8.0500
# ...               ...     ...     ...        ...    ...    ...      ...
# 887                 0       2    male  27.000000      0      0  13.0000
# 888                 1       1  female  19.000000      0      0  30.0000
# 889                 0       3  female  29.699118      1      2  23.4500
# 890                 1       1    male  26.000000      0      0  30.0000
# 891                 0       3    male  32.000000      0      0   7.7500
#
#                Cabin Embarked
# PassengerId
# 1            B96 B98        S
# 2                C85        C
# 3            B96 B98        S
# 4               C123        S
# 5            B96 B98        S
# ...              ...      ...
# 887          B96 B98        S
# 888              B42        S
# 889          B96 B98        S
# 890             C148        C
# 891          B96 B98        Q
#
# [891 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
df['Embarked'] = le.fit_transform(df['Embarked'])
df['Cabin']=le.fit_transform(df['Cabin'])

df
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin  \
# PassengerId
# 1                   0       3    1  22.000000      1      0   7.2500     47
# 2                   1       1    0  38.000000      1      0  71.2833     81
# 3                   1       3    0  26.000000      0      0   7.9250     47
# 4                   1       1    0  35.000000      1      0  53.1000     55
# 5                   0       3    1  35.000000      0      0   8.0500     47
# ...               ...     ...  ...        ...    ...    ...      ...    ...
# 887                 0       2    1  27.000000      0      0  13.0000     47
# 888                 1       1    0  19.000000      0      0  30.0000     30
# 889                 0       3    0  29.699118      1      2  23.4500     47
# 890                 1       1    1  26.000000      0      0  30.0000     60
# 891                 0       3    1  32.000000      0      0   7.7500     47
#
#              Embarked
# PassengerId
# 1                   2
# 2                   0
# 3                   2
# 4                   2
# 5                   2
# ...               ...
# 887                 2
# 888                 2
# 889                 2
# 890                 0
# 891                 1
#
# [891 rows x 9 columns]

# %% [markdown]
# Encoding succesfully done:--
#
#
# for male-1
# for female-0
#
#
# for embarked:-
#     S-2
#     C-0
#     Q-1

# %% [markdown]
# Correlation coefficients are indicators of the strength of the linear relationship between two different variables, x and y. A linear correlation coefficient that is greater than zero indicates a positive relationship. A value that is less than zero signifies a negative relationship. Finally, a value of zero indicates no relationship between the two variables x and y.

# %%
dfc=round(df.corr(),2)
plt.figure(figsize=(12,8),dpi=200)
sns.heatmap(dfc,cmap='Blues',linewidth=1,linecolor='black',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlation tells us about how strong the relationship is between the numerical variables of the dataset.It is in the range of(-1,1).

# %%
# columns having strong positive correlation is denoted as dfc_strong_positive.:--
dfc_strong_positive=dfc[(dfc>0.5)]
dfc_strong_positive
# Out:
#           Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Cabin  Embarked
# Survived       1.0     NaN  NaN  NaN    NaN    NaN   NaN    NaN       NaN
# Pclass         NaN     1.0  NaN  NaN    NaN    NaN   NaN    NaN       NaN
# Sex            NaN     NaN  1.0  NaN    NaN    NaN   NaN    NaN       NaN
# Age            NaN     NaN  NaN  1.0    NaN    NaN   NaN    NaN       NaN
# SibSp          NaN     NaN  NaN  NaN    1.0    NaN   NaN    NaN       NaN
# Parch          NaN     NaN  NaN  NaN    NaN    1.0   NaN    NaN       NaN
# Fare           NaN     NaN  NaN  NaN    NaN    NaN   1.0    NaN       NaN
# Cabin          NaN     NaN  NaN  NaN    NaN    NaN   NaN    1.0       NaN
# Embarked       NaN     NaN  NaN  NaN    NaN    NaN   NaN    NaN       1.0

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.heatmap(dfc_strong_positive,cmap='viridis',annot=True,linecolor='black',linewidths=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# THERE ARE NO VARIABLES HAVING STRONG POSITIVE RELATIONSHIP BETWEEN THEM IN THE DATASET.

# %%
#columns having strong negative correlation is denoted as dfc_strong_negative.
dfc_strong_negative=dfc[(dfc<-0.5)]
dfc_strong_negative
# Out:
#           Survived  Pclass   Sex  Age  SibSp  Parch  Fare  Cabin  Embarked
# Survived       NaN     NaN -0.54  NaN    NaN    NaN   NaN    NaN       NaN
# Pclass         NaN     NaN   NaN  NaN    NaN    NaN -0.55    NaN       NaN
# Sex          -0.54     NaN   NaN  NaN    NaN    NaN   NaN    NaN       NaN
# Age            NaN     NaN   NaN  NaN    NaN    NaN   NaN    NaN       NaN
# SibSp          NaN     NaN   NaN  NaN    NaN    NaN   NaN    NaN       NaN
# Parch          NaN     NaN   NaN  NaN    NaN    NaN   NaN    NaN       NaN
# Fare           NaN   -0.55   NaN  NaN    NaN    NaN   NaN    NaN       NaN
# Cabin          NaN     NaN   NaN  NaN    NaN    NaN   NaN    NaN       NaN
# Embarked       NaN     NaN   NaN  NaN    NaN    NaN   NaN    NaN       NaN

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.heatmap(dfc_strong_negative,cmap='viridis',annot=True,linecolor='black',linewidths=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# PCLASS AND FARE HAS STRONG NEGATIVE RELATIONSHIP BETWEEN THEM.
# SURVIVED AND SEX COLUMNS HAVE STRONG NEGATIVE RELATIONSHIPS BETWEEN THEM.

# %% [markdown]
# ### OUTLIERS DETECTION AND REMOVAL:-

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.boxplot(data=df,palette='colorblind')
plt.xticks(rotation=90);

# %% [markdown]
# There are many outliers present in the dataset shown by boxplot denoted by 'black diamonds'.

# %%
#Outliers Removal:-
from scipy.stats import zscore
threshold=3
z=np.abs(zscore(df))
dfn=df[(z<3).all(axis=1)]
print(dfn.shape)
print(df.shape)
# Out:
# (786, 9)
# (891, 9)

# %%
820/891*100
# Out:
# 92.0314253647587

# %%
X=np.array(df)
from sklearn.covariance import EllipticEnvelope

elpenv = EllipticEnvelope(contamination=0.04, 
                          random_state=1)

# Returns 1 of inliers, -1 for outliers
pred = elpenv.fit_predict(X)

# Extract outliers
outlier_index = np.where(pred==-1)
outlier_values = X[outlier_index]

# %%
outlier_values
# Out:
# array([[  0.        ,   1.        ,   1.        ,  19.        ,
#           3.        ,   2.        , 263.        ,  63.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  29.69911765,
#           1.        ,   0.        , 146.5208    ,  41.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  23.        ,
#           3.        ,   2.        , 263.        ,  63.        ,
#           2.        ],
#        [  0.        ,   1.        ,   1.        ,  24.        ,
#           0.        ,   1.        , 247.5208    ,  36.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  58.        ,
#           0.        ,   0.        , 146.5208    ,  43.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  35.        ,
#           0.        ,   0.        , 512.3292    ,  47.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  58.        ,
#           0.        ,   1.        , 153.4625    ,  57.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  35.        ,
#           0.        ,   0.        , 135.6333    ,  89.        ,
#           2.        ],
#        [  0.        ,   1.        ,   0.        ,   2.        ,
#           1.        ,   2.        , 151.55      ,  62.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  50.        ,
#           0.        ,   1.        , 247.5208    ,  36.        ,
#           0.        ],
#        [  1.        ,   1.        ,   1.        ,   0.92      ,
#           1.        ,   2.        , 151.55      ,  62.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  18.        ,
#           2.        ,   2.        , 262.375     ,  35.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  31.        ,
#           0.        ,   2.        , 164.8667    ,  76.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  40.        ,
#           1.        ,   1.        , 134.5       , 124.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  36.        ,
#           0.        ,   0.        , 135.6333    ,  65.        ,
#           0.        ],
#        [  0.        ,   1.        ,   1.        ,  38.        ,
#           0.        ,   1.        , 153.4625    ,  85.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  41.        ,
#           0.        ,   0.        , 134.5       , 127.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  24.        ,
#           3.        ,   2.        , 263.        ,  63.        ,
#           2.        ],
#        [  0.        ,   1.        ,   1.        ,  22.        ,
#           0.        ,   0.        , 135.6333    ,  47.        ,
#           0.        ],
#        [  0.        ,   1.        ,   1.        ,  27.        ,
#           0.        ,   2.        , 211.5       ,  79.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  42.        ,
#           0.        ,   0.        , 227.525     ,  47.        ,
#           0.        ],
#        [  0.        ,   1.        ,   1.        ,  64.        ,
#           1.        ,   4.        , 263.        ,  63.        ,
#           2.        ],
#        [  0.        ,   1.        ,   0.        ,  25.        ,
#           1.        ,   2.        , 151.55      ,  62.        ,
#           2.        ],
#        [  0.        ,   1.        ,   1.        ,  29.69911765,
#           0.        ,   0.        , 221.7792    ,  88.        ,
#           2.        ],
#        [  0.        ,   1.        ,   1.        ,  29.69911765,
#           0.        ,   0.        , 227.525     ,  47.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  40.        ,
#           0.        ,   0.        , 153.4625    ,  57.        ,
#           2.        ],
#        [  1.        ,   1.        ,   1.        ,  36.        ,
#           0.        ,   1.        , 512.3292    ,  34.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  15.        ,
#           0.        ,   1.        , 211.3375    ,  32.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  18.        ,
#           1.        ,   0.        , 227.525     ,  73.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  22.        ,
#           0.        ,   0.        , 151.55      ,  47.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  38.        ,
#           0.        ,   0.        , 227.525     ,  66.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  29.        ,
#           0.        ,   0.        , 211.3375    ,  32.        ,
#           2.        ],
#        [  1.        ,   1.        ,   1.        ,  35.        ,
#           0.        ,   0.        , 512.3292    ,  15.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  21.        ,
#           2.        ,   2.        , 262.375     ,  35.        ,
#           0.        ],
#        [  1.        ,   1.        ,   0.        ,  43.        ,
#           0.        ,   1.        , 211.3375    ,  22.        ,
#           2.        ],
#        [  1.        ,   1.        ,   0.        ,  45.        ,
#           1.        ,   1.        , 164.8667    ,  47.        ,
#           2.        ]])

# %%
outlier_index_list=list(outlier_index[0])

# %% [markdown]
# converted an array of indexes into a list.

# %%
df_n = df.copy()

# %% [markdown]
# created a copy of 'df' dataframe.

# %%
outlier_index_list
# Out:
# [27,
#  31,
#  88,
#  118,
#  195,
#  258,
#  268,
#  269,
#  297,
#  299,
#  305,
#  311,
#  318,
#  319,
#  325,
#  332,
#  337,
#  341,
#  373,
#  377,
#  380,
#  438,
#  498,
#  527,
#  557,
#  609,
#  679,
#  689,
#  700,
#  708,
#  716,
#  730,
#  737,
#  742,
#  779,
#  856]

# %%
df.drop(index=outlier_index_list,inplace=True)

# %% [markdown]
# created a dataframe after removing all outliers.

# %%
df_n
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin  \
# PassengerId
# 1                   0       3    1  22.000000      1      0   7.2500     47
# 2                   1       1    0  38.000000      1      0  71.2833     81
# 3                   1       3    0  26.000000      0      0   7.9250     47
# 4                   1       1    0  35.000000      1      0  53.1000     55
# 5                   0       3    1  35.000000      0      0   8.0500     47
# ...               ...     ...  ...        ...    ...    ...      ...    ...
# 887                 0       2    1  27.000000      0      0  13.0000     47
# 888                 1       1    0  19.000000      0      0  30.0000     30
# 889                 0       3    0  29.699118      1      2  23.4500     47
# 890                 1       1    1  26.000000      0      0  30.0000     60
# 891                 0       3    1  32.000000      0      0   7.7500     47
#
#              Embarked
# PassengerId
# 1                   2
# 2                   0
# 3                   2
# 4                   2
# 5                   2
# ...               ...
# 887                 2
# 888                 2
# 889                 2
# 890                 0
# 891                 1
#
# [891 rows x 9 columns]

# %%
df
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin  \
# PassengerId
# 1                   0       3    1  22.000000      1      0   7.2500     47
# 2                   1       1    0  38.000000      1      0  71.2833     81
# 3                   1       3    0  26.000000      0      0   7.9250     47
# 4                   1       1    0  35.000000      1      0  53.1000     55
# 5                   0       3    1  35.000000      0      0   8.0500     47
# ...               ...     ...  ...        ...    ...    ...      ...    ...
# 887                 0       2    1  27.000000      0      0  13.0000     47
# 888                 1       1    0  19.000000      0      0  30.0000     30
# 889                 0       3    0  29.699118      1      2  23.4500     47
# 890                 1       1    1  26.000000      0      0  30.0000     60
# 891                 0       3    1  32.000000      0      0   7.7500     47
#
#              Embarked
# PassengerId
# 1                   2
# 2                   0
# 3                   2
# 4                   2
# 5                   2
# ...               ...
# 887                 2
# 888                 2
# 889                 2
# 890                 0
# 891                 1
#
# [855 rows x 9 columns]

# %%
columns_list_ = df.columns
columns_list_
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin',
#        'Embarked'],
#       dtype='object')

# %%
outliers = pd.DataFrame(outlier_values,columns=columns_list_)
outliers['Survived'].sum()
# Out:
# 26.0

# %%
df_n['Survived'].sum()
# Out:
# 342

# %%
df['Survived'].sum() + outliers['Survived'].sum()
# Out:
# 353.0

# %%
855/891*100
# Out:
# 95.95959595959596

# %% [markdown]
# I TRIED DIFFERENT METHODS TO REMOVE OUTLIERS:-
# ZSCORE AND
#
# ELLIPTIC ENVELOPE.
#
#
#
# ZSCORE METHOD LED TO MORE LOSS OF DATA(AROUND 8%),SO I PREFERRED ELLIPTIC ENVELOPE TO REMOVE OUTLIERS WHICH REMOVED AROUND 5% OF THE DATA.

# %% [markdown]
# After removing the outliers,the 'df' is the the dataframe ready to be prepared for further machine learning process. Around 5% of the data has been removed because they have been declared outliers.

# %%
df
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin  \
# PassengerId
# 1                   0       3    1  22.000000      1      0   7.2500     47
# 2                   1       1    0  38.000000      1      0  71.2833     81
# 3                   1       3    0  26.000000      0      0   7.9250     47
# 4                   1       1    0  35.000000      1      0  53.1000     55
# 5                   0       3    1  35.000000      0      0   8.0500     47
# ...               ...     ...  ...        ...    ...    ...      ...    ...
# 887                 0       2    1  27.000000      0      0  13.0000     47
# 888                 1       1    0  19.000000      0      0  30.0000     30
# 889                 0       3    0  29.699118      1      2  23.4500     47
# 890                 1       1    1  26.000000      0      0  30.0000     60
# 891                 0       3    1  32.000000      0      0   7.7500     47
#
#              Embarked
# PassengerId
# 1                   2
# 2                   0
# 3                   2
# 4                   2
# 5                   2
# ...               ...
# 887                 2
# 888                 2
# 889                 2
# 890                 0
# 891                 1
#
# [855 rows x 9 columns]

# %%
df_new = df

# %%
df_new
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin  \
# PassengerId
# 1                   0       3    1  22.000000      1      0   7.2500     47
# 2                   1       1    0  38.000000      1      0  71.2833     81
# 3                   1       3    0  26.000000      0      0   7.9250     47
# 4                   1       1    0  35.000000      1      0  53.1000     55
# 5                   0       3    1  35.000000      0      0   8.0500     47
# ...               ...     ...  ...        ...    ...    ...      ...    ...
# 887                 0       2    1  27.000000      0      0  13.0000     47
# 888                 1       1    0  19.000000      0      0  30.0000     30
# 889                 0       3    0  29.699118      1      2  23.4500     47
# 890                 1       1    1  26.000000      0      0  30.0000     60
# 891                 0       3    1  32.000000      0      0   7.7500     47
#
#              Embarked
# PassengerId
# 1                   2
# 2                   0
# 3                   2
# 4                   2
# 5                   2
# ...               ...
# 887                 2
# 888                 2
# 889                 2
# 890                 0
# 891                 1
#
# [855 rows x 9 columns]

# %% [markdown]
# created a new dataframe after removing outliers.

# %%
df_new = df_new.reset_index(drop=True)

# %% [markdown]
# reset index for the data after removing outliers.

# %%
df_new
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin  Embarked
# 0           0       3    1  22.000000      1      0   7.2500     47         2
# 1           1       1    0  38.000000      1      0  71.2833     81         0
# 2           1       3    0  26.000000      0      0   7.9250     47         2
# 3           1       1    0  35.000000      1      0  53.1000     55         2
# 4           0       3    1  35.000000      0      0   8.0500     47         2
# ..        ...     ...  ...        ...    ...    ...      ...    ...       ...
# 850         0       2    1  27.000000      0      0  13.0000     47         2
# 851         1       1    0  19.000000      0      0  30.0000     30         2
# 852         0       3    0  29.699118      1      2  23.4500     47         2
# 853         1       1    1  26.000000      0      0  30.0000     60         0
# 854         0       3    1  32.000000      0      0   7.7500     47         1
#
# [855 rows x 9 columns]

# %% [markdown]
# ### SKEWNESS REMOVAL:-¶

# %%
df_new.skew()
# Out:
# Survived    0.484583
# Pclass     -0.643518
# Sex        -0.626031
# Age         0.445034
# SibSp       3.608511
# Parch       2.634862
# Fare        4.827749
# Cabin       2.289466
# Embarked   -1.257894
# dtype: float64

# %%
df_new['SibSp']=np.sqrt(df_new['SibSp'])
df_new['Parch']=np.sqrt(df_new['Parch'])
df_new['Fare']=np.sqrt(df_new['Fare'])

# %%
df_new.skew()
# Out:
# Survived    0.484583
# Pclass     -0.643518
# Sex        -0.626031
# Age         0.445034
# SibSp       1.420175
# Parch       1.511927
# Fare        2.116626
# Cabin       2.289466
# Embarked   -1.257894
# dtype: float64

# %%
df_new['SibSp']=np.cbrt(df_new['SibSp'])
df_new['Parch']=np.cbrt(df_new['Parch'])
df_new['Fare']=np.cbrt(df_new['Fare'])

# %%
df_new.skew()
# Out:
# Survived    0.484583
# Pclass     -0.643518
# Sex        -0.626031
# Age         0.445034
# SibSp       0.837847
# Parch       1.254723
# Fare       -0.986025
# Cabin       2.289466
# Embarked   -1.257894
# dtype: float64

# %%
skew_new=df_new.skew()
skew_new
# Out:
# Survived    0.484583
# Pclass     -0.643518
# Sex        -0.626031
# Age         0.445034
# SibSp       0.837847
# Parch       1.254723
# Fare       -0.986025
# Cabin       2.289466
# Embarked   -1.257894
# dtype: float64

# %%
skew_new=skew_new.reset_index()
skew_new
# Out:
#       index         0
# 0  Survived  0.484583
# 1    Pclass -0.643518
# 2       Sex -0.626031
# 3       Age  0.445034
# 4     SibSp  0.837847
# 5     Parch  1.254723
# 6      Fare -0.986025
# 7     Cabin  2.289466
# 8  Embarked -1.257894

# %%
skew_new.rename(columns={'index':'column_names',0:'skewness'},inplace= True)
skew_new
# Out:
#   column_names  skewness
# 0     Survived  0.484583
# 1       Pclass -0.643518
# 2          Sex -0.626031
# 3          Age  0.445034
# 4        SibSp  0.837847
# 5        Parch  1.254723
# 6         Fare -0.986025
# 7        Cabin  2.289466
# 8     Embarked -1.257894

# %%
plt.figure(figsize=(12,8),dpi=200)
sns.scatterplot(data=skew_new,x='column_names',y='skewness')
plt.xticks(rotation=90)
plt.yticks(np.arange(-5, 20, step=5))
plt.axhline(y = 0, color = 'g', linestyle = '-')
plt.axhline(y = 0.5, color = 'r', linestyle = '-')
plt.axhline(y = -0.5, color = 'r', linestyle = '-');

# %% [markdown]
# I TRIED TO REMOVE SKEWNESS FROM THE DATA TO SOME EXTENT BUT THERE IS STILL SOME SKEWNESS IN THE DATASET.
#
# REMOVAL OF SKEWNESS IS NECESSARY FOR EFFECTIVE MODEL PERFORMANCE.

# %%
df_new.shape
# Out:
# (855, 9)

# %%
df_new
# Out:
#      Survived  Pclass  Sex        Age  SibSp     Parch      Fare  Cabin  \
# 0           0       3    1  22.000000    1.0  0.000000  1.391200     47
# 1           1       1    0  38.000000    1.0  0.000000  2.036251     81
# 2           1       3    0  26.000000    0.0  0.000000  1.411995     47
# 3           1       1    0  35.000000    1.0  0.000000  1.938723     55
# 4           0       3    1  35.000000    0.0  0.000000  1.415683     47
# ..        ...     ...  ...        ...    ...       ...       ...    ...
# 850         0       2    1  27.000000    0.0  0.000000  1.533406     47
# 851         1       1    0  19.000000    0.0  0.000000  1.762734     30
# 852         0       3    0  29.699118    1.0  1.122462  1.691832     47
# 853         1       1    1  26.000000    0.0  0.000000  1.762734     60
# 854         0       3    1  32.000000    0.0  0.000000  1.406750     47
#
#      Embarked
# 0           2
# 1           0
# 2           2
# 3           2
# 4           2
# ..        ...
# 850         2
# 851         2
# 852         2
# 853         0
# 854         1
#
# [855 rows x 9 columns]

# %%
df_new['Survived'].value_counts()
# Out:
# 0    528
# 1    327
# Name: Survived, dtype: int64

# %% [markdown]
# checking how much the data is imbalanced.

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855 entries, 0 to 854
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  855 non-null    int64
#  1   Pclass    855 non-null    int64
#  2   Sex       855 non-null    int32
#  3   Age       855 non-null    float64
#  4   SibSp     855 non-null    float64
#  5   Parch     855 non-null    float64
#  6   Fare      855 non-null    float64
#  7   Cabin     855 non-null    int32
#  8   Embarked  855 non-null    int32
# dtypes: float64(4), int32(3), int64(2)
# memory usage: 50.2 KB

# %%
#seperating the target lable and features:-
X=df_new.drop('Survived',axis=1) 
y=df_new['Survived']

# %% [markdown]
# seperated the data into X and y.

# %% [markdown]
# ## MACHINE LEARNING PROCESS:-¶

# %%
from sklearn.model_selection import cross_val_score,cross_validate
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# imported the necessary libraries and metrics for classification task from sklearn library.

# %%
#Assigning the variables to each models-
lgbc = LGBMClassifier(random_state=100)
xgbc = XGBClassifier(n_estimators=100,random_state=100,max_depth=50)
rf = RandomForestClassifier(random_state=100)
ad = AdaBoostClassifier(random_state=100)
gb=GradientBoostingClassifier(random_state=100)
nbg=GaussianNB()
lg=LogisticRegression(random_state=100)
l50=[rf,ad,gb,nbg,lgbc,xgbc]

#seperating the training data and test data:-
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %% [markdown]
# DONE THE TRAIN TEST SPLIT AND ASSIGNED EACH MODEL TO EACH VARIABLE.

# %% [markdown]
# ### SCALING AND STANDARDIZATION:-¶

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
sX_train = s.fit_transform(X_train)
sX_test = s.transform(X_test)

# %% [markdown]
# Only training data has been both fit and transformed but the test data has only been transformed. '.fit' means calculating necessary statistics from the data and '.transform' only scales the data. test data should not be fit because that would lead to assumption of the prior knowledge of the test data and test data is the data, machine learning model need to predict fairly without having any knowledge of the test data.

# %%
from sklearn.metrics import SCORERS
s=SCORERS
s.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %%
for m in l50:
    m.fit(sX_train,y_train)
    preds = m.predict(sX_test)
    accu= accuracy_score(y_test,preds)
    precision=precision_score(y_test,preds)
    recall=recall_score(y_test,preds)
    print('model_name :',m)
    print(confusion_matrix(y_test,preds))
    print('accuracy: ',accu)
    print('precision: ',precision)
    print('recall: ',recall)
    plot_confusion_matrix(m,sX_test,y_test)
    print('cross val score for accuracy: ',cross_val_score(m,X,y,cv=10,scoring='accuracy').mean())
    print('cross val score for precision: ',cross_val_score(m,X,y,cv=10,scoring='precision').mean())
    print('cross val score for recall: ',cross_val_score(m,X,y,cv=10,scoring='recall').mean())
    print('difference between model scores and model_cross validation scores below:--  ',m)
    print('diffrence in accuracy: ',(accu-cross_val_score(m,X,y,cv=10,scoring='accuracy').mean()))
    print('diffrence in precision: ',(precision-cross_val_score(m,X,y,cv=10,scoring='precision').mean()))
    print('diffrence in recall: ',(recall-cross_val_score(m,X,y,cv=10,scoring='recall').mean()))
    print('\n')
    print('\n')
# Out:
# model_name : RandomForestClassifier(random_state=100)
# [[144  18]
#  [ 27  68]]
# accuracy:  0.8249027237354085
# precision:  0.7906976744186046
# recall:  0.7157894736842105
# cross val score for accuracy:  0.8187824897400822
# cross val score for precision:  0.7770207834551257
# cross val score for recall:  0.7424242424242424
# difference between model scores and model_cross validation scores below:--   RandomForestClassifier(random_state=100)
# diffrence in accuracy:  0.006120233995326352
# diffrence in precision:  0.013676890963478905
# diffrence in recall:  -0.0266347687400319
#
#
#
#
# model_name : AdaBoostClassifier(random_state=100)
# [[137  25]
#  [ 21  74]]
# accuracy:  0.8210116731517509
# precision:  0.7474747474747475
# recall:  0.7789473684210526
# cross val score for accuracy:  0.8047469220246238
# cross val score for precision:  0.7465594822491374
# cross val score for recall:  0.7425189393939394
# difference between model scores and model_cross validation scores below:--   AdaBoostClassifier(random_state=100)
# diffrence in accuracy:  0.01626475112712711
# diffrence in precision:  0.0009152652256101401
# diffrence in recall:  0.036428429027113185
#
#
#
#
# model_name : GradientBoostingClassifier(random_state=100)
# [[150  12]
#  [ 25  70]]
# accuracy:  0.8560311284046692
# precision:  0.8536585365853658
# recall:  0.7368421052631579
# cross val score for accuracy:  0.8293023255813955
# cross val score for precision:  0.815052717482385
# cross val score for recall:  0.7150568181818182
# difference between model scores and model_cross validation scores below:--   GradientBoostingClassifier(random_state=100)
# diffrence in accuracy:  0.026728802823273723
# diffrence in precision:  0.03860581910298089
# diffrence in recall:  0.021785287081339644
#
#
#
#
# model_name : GaussianNB()
# [[132  30]
#  [ 26  69]]
# accuracy:  0.7821011673151751
# precision:  0.696969696969697
# recall:  0.7263157894736842
# cross val score for accuracy:  0.7557045143638851
# cross val score for precision:  0.6762120966880986
# cross val score for recall:  0.694128787878788
# difference between model scores and model_cross validation scores below:--   GaussianNB()
# diffrence in accuracy:  0.02639665295129001
# diffrence in precision:  0.020757600281598454
# diffrence in recall:  0.03218700159489629
#
#
#
#
# model_name : LGBMClassifier(random_state=100)
# [[144  18]
#  [ 30  65]]
# accuracy:  0.8132295719844358
# precision:  0.7831325301204819
# recall:  0.6842105263157895
# cross val score for accuracy:  0.8292612859097126
# cross val score for precision:  0.7898826690554018
# cross val score for recall:  0.7520833333333334
# difference between model scores and model_cross validation scores below:--   LGBMClassifier(random_state=100)
# diffrence in accuracy:  -0.016031713925276803
# diffrence in precision:  -0.006750138934919936
# diffrence in recall:  -0.06787280701754395
#
#
#
#
# [17:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# model_name : XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=50,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=100,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# [[143  19]
#  [ 31  64]]
# accuracy:  0.8054474708171206
# precision:  0.7710843373493976
# recall:  0.6736842105263158
# [17:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# cross val score for accuracy:  0.8198768809849521
# [17:50:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# cross val score for precision:  0.7807806534614835
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# cross val score for recall:  0.7366477272727273
# difference between model scores and model_cross validation scores below:--   XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=50,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=100,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# diffrence in accuracy:  -0.014429410167831502
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# diffrence in precision:  -0.009696316112085879
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:50:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# diffrence in recall:  -0.06296351674641154

# %% [markdown]
# The lower the difference in scores,the better the model is for being selected for hyperparameter tuning.GRADIENT BOOSTING CLASSIFER HAS DONE QUITE WELL OF ALL THE MODELS.

# %% [markdown]
# ## AOC-ROC CURVE AND SCORE:--

# %%
from sklearn.metrics import roc_auc_score,roc_curve

# %%
xgbc.fit(sX_train,y_train,eval_metric='error')
y_pred_prob = xgbc.predict_proba(sX_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='XgboostClassifier')
plt.xlabel('False_positive_rate')
plt.ylabel('True_positive_rate')
plt.title('XgboostClassifier');
auc_score = roc_auc_score(y_test,xgbc.predict(sX_test))
print(auc_score)
# Out:
# 0.7782001299545159

# %%
lgbc.fit(sX_train,y_train)
y_pred_prob = lgbc.predict_proba(sX_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='LightgbmClassifier')
plt.xlabel('False_positive_rate')
plt.ylabel('True_positive_rate')
plt.title('LightgbmClassifier');
auc_score = roc_auc_score(y_test,lgbc.predict(sX_test))
print(auc_score)
# Out:
# 0.7865497076023391

# %%
ad.fit(sX_train,y_train)
y_pred_prob = ad.predict_proba(sX_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='ADABOOST CLASSIFIER')
plt.xlabel('False_positive_rate')
plt.ylabel('True_positive_rate')
plt.title('ADABOOST CLASSIFIER');
auc_score = roc_auc_score(y_test,ad.predict(sX_test))
print(auc_score)
# Out:
# 0.8123131903833658

# %%
gb.fit(sX_train,y_train)
y_pred_prob = gb.predict_proba(sX_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Gradient boosting Classifier')
plt.xlabel('False_positive_rate')
plt.ylabel('True_positive_rate')
plt.title('Gradient boosting Classifier');
auc_score = roc_auc_score(y_test,gb.predict(sX_test))
print(auc_score)
# Out:
# 0.8313840155945419

# %%
rf.fit(sX_train,y_train)
y_pred_prob = rf.predict_proba(sX_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Random forest Classifier')
plt.xlabel('False_positive_rate')
plt.ylabel('True_positive_rate')
plt.title('Random forestClassifier');
auc_score = roc_auc_score(y_test,rf.predict(sX_test))
print(auc_score)
# Out:
# 0.8023391812865497

# %%
lg.fit(sX_train,y_train)
y_pred_prob = lg.predict_proba(sX_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Logistic Regression')
plt.xlabel('False_positive_rate')
plt.ylabel('True_positive_rate')
plt.title('Logistic Regression');
auc_score = roc_auc_score(y_test,lg.predict(sX_test))
print(auc_score)
# Out:
# 0.7983430799220272

# %%
nbg.fit(sX_train,y_train)
y_pred_prob = nbg.predict_proba(sX_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Gaussian naive bayes')
plt.xlabel('False_positive_rate')
plt.ylabel('True_positive_rate')
plt.title('gaussian naive bayes');
auc_score = roc_auc_score(y_test,nbg.predict(sX_test))
print(auc_score)
# Out:
# 0.7705653021442496

# %% [markdown]
# ADABOOST CLASSIFIER AND GRADIENT BOOSTING CLASSIFIER HAS BETTER AUC ROC SCORE THAN THAT OF ALL THE MODELS.

# %% [markdown]
# ### SELECTION OF MODELS FOR HYPERPARAMETER TUNING:-
# GRADIENT BOOSTING WAS THE BEST AMONG ALL THE MODELS IN ALL METRICS.

# %% [markdown]
# ## GRID SEARCH CV:-

# %%
from sklearn.model_selection import GridSearchCV

# %%
gbp = {'n_estimators':[400,300,250,500],'learning_rate':[0.1,0.3,0.5,0.2,0.0001,1.0],'max_features':['auto','log2','sqrt']}
lgbmp = {'n_estimators': [400,200,100],
         'reg_alpha': [0,1,0.5,1.1, 1.2],'reg_lambda': [0,0.5,1,1.1, 1.2],
        'learning_rate':[0.1,0.2,1,0.001,0.0002],'n_jobs':[1,2]}

# %%
g1=GridSearchCV(lgbc,param_grid=lgbmp,cv=5)
g2=GridSearchCV(gb,param_grid=gbp,cv=5)

# %%
print(g1)
g1.fit(sX_train,y_train)
y_pred=g1.predict(sX_test)
print('ACCURACY_SCORE')
print(accuracy_score(y_test,y_pred))
print('classification_report')
print(classification_report(y_test,y_pred))
print('confusion_matrix')
print(confusion_matrix(y_test,y_pred))
print('precision_score:',precision_score(y_test,y_pred))
print('recall_score:',recall_score(y_test,y_pred))
print(g1)
auc_score =roc_auc_score(y_test,y_pred)
print('AUC_score',auc_score)
print(g1.best_params_)
print('\n')
print('\n')
# Out:
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=100),
#              param_grid={'learning_rate': [0.1, 0.2, 1, 0.001, 0.0002],
#                          'n_estimators': [400, 200, 100], 'n_jobs': [1, 2],
#                          'reg_alpha': [0, 1, 0.5, 1.1, 1.2],
#                          'reg_lambda': [0, 0.5, 1, 1.1, 1.2]})
# ACCURACY_SCORE
# 0.8443579766536965
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       162
#            1       0.83      0.73      0.78        95
#
#     accuracy                           0.84       257
#    macro avg       0.84      0.82      0.83       257
# weighted avg       0.84      0.84      0.84       257
#
# confusion_matrix
# [[148  14]
#  [ 26  69]]
# precision_score: 0.8313253012048193
# recall_score: 0.7263157894736842
# GridSearchCV(cv=5, estimator=LGBMClassifier(random_state=100),
#              param_grid={'learning_rate': [0.1, 0.2, 1, 0.001, 0.0002],
#                          'n_estimators': [400, 200, 100], 'n_jobs': [1, 2],
#                          'reg_alpha': [0, 1, 0.5, 1.1, 1.2],
#                          'reg_lambda': [0, 0.5, 1, 1.1, 1.2]})
# AUC_score 0.8199480181936324
# {'learning_rate': 0.1, 'n_estimators': 100, 'n_jobs': 1, 'reg_alpha': 1.2, 'reg_lambda': 1.2}

# %%
print(g2)
g2.fit(sX_train,y_train)
y_pred=g2.predict(sX_test)
print('ACCURACY_SCORE')
print(accuracy_score(y_test,y_pred))
print('classification_report')
print(classification_report(y_test,y_pred))
print('confusion_matrix')
print(confusion_matrix(y_test,y_pred))
print('precision_score:',precision_score(y_test,y_pred))
print('recall_score:',recall_score(y_test,y_pred))
print(g2)
auc_score =roc_auc_score(y_test,y_pred)
print('AUC_score',auc_score)
print(g2.best_params_)
print('\n')
print('\n')
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(random_state=100),
#              param_grid={'learning_rate': [0.1, 0.3, 0.5, 0.2, 0.0001, 1.0],
#                          'max_features': ['auto', 'log2', 'sqrt'],
#                          'n_estimators': [400, 300, 250, 500]})
# ACCURACY_SCORE
# 0.8093385214007782
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       162
#            1       0.78      0.67      0.72        95
#
#     accuracy                           0.81       257
#    macro avg       0.80      0.78      0.79       257
# weighted avg       0.81      0.81      0.81       257
#
# confusion_matrix
# [[144  18]
#  [ 31  64]]
# precision_score: 0.7804878048780488
# recall_score: 0.6736842105263158
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(random_state=100),
#              param_grid={'learning_rate': [0.1, 0.3, 0.5, 0.2, 0.0001, 1.0],
#                          'max_features': ['auto', 'log2', 'sqrt'],
#                          'n_estimators': [400, 300, 250, 500]})
# AUC_score 0.7812865497076023
# {'learning_rate': 0.3, 'max_features': 'log2', 'n_estimators': 400}

# %% [markdown]
# LIGHT GBM CLASSIFIER WAS THE BEST PERFORMER WITH GRID SEARCH CV.

# %%
light_classifier = lightgbm_classifier=LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
               importance_type='split', learning_rate=0.1, max_depth=60,
               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
               n_estimators=100, n_jobs=1, num_leaves=31, objective=None,
               random_state=100, reg_alpha=1.2, reg_lambda=1.2, silent=True,
               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
print(light_classifier)
light_classifier.fit(sX_train,y_train)
y_pred=light_classifier.predict(sX_test)
print('ACCURACY_SCORE')
print(accuracy_score(y_test,y_pred))
print('classification_report')
print(classification_report(y_test,y_pred))
print('confusion_matrix')
print(confusion_matrix(y_test,y_pred))
print('precision_score:',precision_score(y_test,y_pred))
print('recall_score:',recall_score(y_test,y_pred))
print(light_classifier)
auc_score =roc_auc_score(y_test,y_pred)
print('AUC_score',auc_score)
plot_confusion_matrix(light_classifier,sX_test,y_test)
# Out:
# LGBMClassifier(max_depth=60, n_jobs=1, random_state=100, reg_alpha=1.2,
#                reg_lambda=1.2)
# ACCURACY_SCORE
# 0.8443579766536965
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88       162
#            1       0.83      0.73      0.78        95
#
#     accuracy                           0.84       257
#    macro avg       0.84      0.82      0.83       257
# weighted avg       0.84      0.84      0.84       257
#
# confusion_matrix
# [[148  14]
#  [ 26  69]]
# precision_score: 0.8313253012048193
# recall_score: 0.7263157894736842
# LGBMClassifier(max_depth=60, n_jobs=1, random_state=100, reg_alpha=1.2,
#                reg_lambda=1.2)
# AUC_score 0.8199480181936324

# %% [markdown]
# ## SAVING THE MODEL:-

# %%
import joblib

# %%
joblib.dump(light_classifier,'light_gbm_bestmodel_classifier.obj')
# Out:
# ['light_gbm_bestmodel_classifier.obj']

# %%
loaded_model = joblib.load('light_gbm_bestmodel_classifier.obj')
loaded_model
# Out:
# LGBMClassifier(max_depth=60, n_jobs=1, random_state=100, reg_alpha=1.2,
#                reg_lambda=1.2)
